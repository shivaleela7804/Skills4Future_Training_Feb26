# %%
print('welcome to training session')
# Out:
# welcome to training session

# %% [raw]
# print('Welcome to SkillsFuture Training Session!')

# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3

# %% [markdown]
# # This is my first comment

# %%
name = 'Shivaleela'
age = 21

# %%
print(f'Hello, I am {name} and {age} year old')
# Out:
# Hello, I am Shivaleela and 21 year old

# %%
id(age)
# Out:
# 140721800902184

# %%
hex(id(age))
# Out:
# '0x7ffc58f47628'

# %%
x = 3
y = 5

# %%
x + y
# Out:
# 8

# %%
a = 2
b = 4

# %%
c = a/b

# %%
x = 12
id(x)
# Out:
# 140721800901896

# %%
y = 12
id(y)
# Out:
# 140721800901896

# %%
# Data structures - list, tuple, dic, set

# %%
# List - collection of any data type; []; mutable 
lst = ['apple', 'grapes','kiwi', 'mango', 'dragonfruit']

# %%
lst
# Out:
# ['apple', 'grapes', 'kiwi', 'mango', 'dragonfruit']

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
# append - 'banana'
lst.append('banana')
lst
# Out:
# ['apple', 'grapes', 'kiwi', 'mango', 'dragonfruit', 'banana']

# %%
lst.index('kiwi')
# Out:
# 2

# %%
# insert - 'orange'
lst.insert(4, 'orange' )

# %%
lst
# Out:
# ['apple', 'grapes', 'kiwi', 'mango', 'orange', 'dragonfruit', 'banana']

# %%
# pop and remove
lst.pop(-2)
# Out:
# 'dragonfruit'

# %%
lst.remove('orange')
lst
# Out:
# ['apple', 'grapes', 'kiwi', 'mango', 'banana']

# %%
lst.reverse()

# %%
lst
# Out:
# ['banana', 'mango', 'kiwi', 'grapes', 'apple']

# %%
lst.sort()
lst
# Out:
# ['apple', 'banana', 'grapes', 'kiwi', 'mango']

# %%
lst.clear()

# %%
lst
# Out:
# []

# %%
# Tuple - immutable  | () all dt
tup = ('AIEMS', 'BIDADI', 56210.9)
tup
# Out:
# ('AIEMS', 'BIDADI', 56210.9)

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
tup.count(15)
# Out:
# 0

# %%
tup.index('BIDADI')
# Out:
# 1

# %%
# Set - duplicates, {}
set1 = {2, 2, 2, 3, 6, 8, 10}
set1
# Out:
# {2, 3, 6, 8, 10}

# %%
dir(set)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
set2 ={6, 7, 9, 10, 13, 15}
set2
# Out:
# {6, 7, 9, 10, 13, 15}

# %%
set1.union(set2)
# Out:
# {2, 3, 6, 7, 8, 9, 10, 13, 15}

# %%
set1.intersection(set2)
# Out:
# {6, 10}

# %%
# dictionary  - k:v  | {} | keys are always unique
dit = {'name': 'Shivaleela', 'age' : 21}
dit
# Out:
# {'name': 'Shivaleela', 'age': 21}

# %%
dir(dit)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
dir(dict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
dit.values()
# Out:
# dict_values(['Shivaleela', 21])

# %%
dit.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
print('check')
# Out:
# check

# %%
# conditional statements
# if condition
x = 10
if x >= 10:
    print('True!')
# Out:
# True!

# %%
x = 9
if x >= 10:
    print('True!')

# %%
if x >= 10:
    print('True!')
else:
    print('False')
# Out:
# False

# %%
marks = 90
if marks >= 90:
    print('A+')
elif marks >= 70 & marks <= 89:
    print('A')
elif marks >= 60 & marks <= 69:
    print('B')
else:
    print('C')
# Out:
# A+

# %%
marks = 55
if marks >= 90:
    print('A+')
elif marks >= 70 & marks <= 89:
    print('A')
elif marks >= 60 & marks <= 69:
    print('B')
else:
    print('C')
# Out:
# A

# %%
marks = 78
if marks >= 90:
    print('A+')
elif marks >= 70 and marks <= 89:
    print('A')
elif marks >= 60 and marks <= 69:
    print('B')
else:
    print('C')
# Out:
# A

# %%
marks = 61
if marks >= 90:
    print('A+')
elif marks >= 70 & marks <= 89:
    print('A')
elif marks >= 60 & marks <= 69:
    print('B')
else:
    print('C')
# Out:
# A

# %%
for i in range(9):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
for rms in range(9):
    print(rms)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
for a in range (0, 11, 12):
    print(a)
# Out:
# 0

# %%
for a in range(0, 11, 2):
    print(a)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
for rms in range(1, 11, 3):
    print(rms)
# Out:
# 1
# 4
# 7
# 10

# %%
for rms in range(1, 12, 3):
    print(rms)
# Out:
# 1
# 4
# 7
# 10

# %%
# while loop
count = 0
while count  <= 5:
    print(count)
    count = count + 1 #incremental
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
count=1
while count <= 5:
    print(count)
    count = count + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
count=5
while count >= 1:
    print(count)
    count = count - 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
count=5
while count >= 0:
    print(count)
    count = count - 1
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %%
for i in range(5):
    if i == 3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(5):
    if i == 4:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
# List Comprehension []
x = 2

# %%
def funcname():
    
    return

# %%
def addition(a, b):
    return a+b

# %%
addition(3, 2)
# Out:
# 5

# %%
def add1(a, b, c):
    return a + b + c

add1(3, 4, 5)
# Out:
# 12

# %%
def add2(*args):
    return sum(args)

# %%
add2(2, 9, 89, 45, 23, 54, 12, 49)
# Out:
# 283

# %%
def add2(*args):
    return sum(args)

# %%
add2(35 , 54, 1)
# Out:
# 90

# %%
def greet():
    print('HELLO!')

# %%
greet()
# Out:
# HELLO!

# %%
import pandas as pd
import numpy as np

# %%
#load the dataset 
df = pd.read_csv(r'C:\Users\shiva\aiems\Student_Behaviour.csv')
df.head()
# Out:
#   Certification Course  Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 0                   No    Male        BCA       100.0        58.0       79.0
# 1                   No  Female        BCA        90.0        40.0       70.0
# 2                  Yes    Male        BCA       159.0        78.0       69.5
# 3                  Yes  Female        BCA       147.0        20.0       70.0
# 4                   No    Male        BCA       170.0        54.0       40.0
#
#    12th Mark  college mark        hobbies daily studing time  \
# 0       65.0          80.0    Video Games      0 - 30 minute
# 1       80.0          70.0         Cinema     30 - 60 minute
# 2       61.0          55.0         Cinema         1 - 2 Hour
# 3       59.0          58.0  Reading books         1 - 2 Hour
# 4       65.0          30.0    Video Games     30 - 60 minute
#
#   prefer to study in  salary expectation Do you like your degree?  \
# ...

# %%
#load the dataset 
df = pd.read_csv(r'C:\Users\shiva\aiems\Student_Behaviour.csv')
df.head(3)
# Out:
#   Certification Course  Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 0                   No    Male        BCA       100.0        58.0       79.0
# 1                   No  Female        BCA        90.0        40.0       70.0
# 2                  Yes    Male        BCA       159.0        78.0       69.5
#
#    12th Mark  college mark      hobbies daily studing time prefer to study in  \
# 0       65.0          80.0  Video Games      0 - 30 minute            Morning
# 1       80.0          70.0       Cinema     30 - 60 minute            Morning
# 2       61.0          55.0       Cinema         1 - 2 Hour            Anytime
#
#    salary expectation Do you like your degree?  \
# 0               40000                       No
# 1               15000                      Yes
# 2               13000                      Yes
#
#   willingness to pursue a career based on their degree   social medai & video  \
# ...

# %%
# how to no. of rows/cols
df.shape
# Out:
# (235, 19)

# %%
print(f'The no. of rows:{df.shape[0]} and cols:{df.shape[1]}')
# Out:
# The no. of rows:235 and cols:19

# %%
# info of a dataset
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 19 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Certification Course                                    235 non-null    str
#  1   Gender                                                  235 non-null    str
#  2   Department                                              235 non-null    str
#  3   Height(CM)                                              235 non-null    float64
#  4   Weight(KG)                                              235 non-null    float64
#  5   10th Mark                                               235 non-null    float64
#  6   12th Mark                                               235 non-null    float64
#  7   college mark                                            235 non-null    float64
# ...

# %%
# stat
df.describe()
# Out:
#        Height(CM)  Weight(KG)   10th Mark   12th Mark  college mark  \
# count  235.000000  235.000000  235.000000  235.000000    235.000000
# mean   157.402128   60.803830   76.842128   68.780128     70.660553
# std     21.510805   14.895844   13.050800   11.016533     15.727446
# min      4.500000   20.000000    7.400000   45.000000      1.000000
# 25%    152.000000   50.000000   70.000000   60.000000     60.000000
# 50%    160.000000   60.000000   80.000000   69.000000     70.000000
# 75%    170.000000   70.000000   86.250000   76.000000     80.000000
# max    192.000000  106.000000   98.000000   94.000000    100.000000
#
#        salary expectation
# count        2.350000e+02
# mean         3.248168e+04
# std          1.113146e+05
# min          0.000000e+00
# 25%          1.500000e+04
# 50%          2.000000e+04
# 75%          2.500000e+04
# max          1.500000e+06

# %%
# access a col
df.columns
# Out:
# Index(['Certification Course', 'Gender', 'Department', 'Height(CM)',
#        'Weight(KG)', '10th Mark', '12th Mark', 'college mark', 'hobbies',
#        'daily studing time', 'prefer to study in', 'salary expectation',
#        'Do you like your degree?',
#        'willingness to pursue a career based on their degree  ',
#        'social medai & video', 'Travelling Time ', 'Stress Level ',
#        'Financial Status', 'part-time job'],
#       dtype='str')

# %%
df.Gender
# Out:
# 0        Male
# 1      Female
# 2        Male
# 3      Female
# 4        Male
#         ...
# 230      Male
# 231      Male
# 232    Female
# 233    Female
# 234    Female
# Name: Gender, Length: 235, dtype: str

# %%
df.Certification Course
# Out:
#   Cell In[81], line 1
#     df.Certification Course
#                      ^
# SyntaxError: invalid syntax

# %%
df['Certification Course']
# Out:
# 0       No
# 1       No
# 2      Yes
# 3      Yes
# 4       No
#       ...
# 230    Yes
# 231    Yes
# 232    Yes
# 233    Yes
# 234     No
# Name: Certification Course, Length: 235, dtype: str

# %%
# rows - loc method
df.loc[0:5]
# Out:
#   Certification Course  Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 0                   No    Male        BCA       100.0        58.0       79.0
# 1                   No  Female        BCA        90.0        40.0       70.0
# 2                  Yes    Male        BCA       159.0        78.0       69.5
# 3                  Yes  Female        BCA       147.0        20.0       70.0
# 4                   No    Male        BCA       170.0        54.0       40.0
# 5                  Yes  Female        BCA       139.0        33.0       90.0
#
#    12th Mark  college mark        hobbies daily studing time  \
# 0       65.0          80.0    Video Games      0 - 30 minute
# 1       80.0          70.0         Cinema     30 - 60 minute
# 2       61.0          55.0         Cinema         1 - 2 Hour
# 3       59.0          58.0  Reading books         1 - 2 Hour
# 4       65.0          30.0    Video Games     30 - 60 minute
# ...

# %%
# rows - loc method
df.loc[2:5]
# Out:
#   Certification Course  Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 2                  Yes    Male        BCA       159.0        78.0       69.5
# 3                  Yes  Female        BCA       147.0        20.0       70.0
# 4                   No    Male        BCA       170.0        54.0       40.0
# 5                  Yes  Female        BCA       139.0        33.0       90.0
#
#    12th Mark  college mark        hobbies daily studing time  \
# 2       61.0          55.0         Cinema         1 - 2 Hour
# 3       59.0          58.0  Reading books         1 - 2 Hour
# 4       65.0          30.0    Video Games     30 - 60 minute
# 5       75.0          70.0         Cinema     30 - 60 minute
#
#   prefer to study in  salary expectation Do you like your degree?  \
# 2            Anytime               13000                      Yes
# 3            Anytime             1500000                       No
# 4            Morning               50000                      Yes
# ...

# %%
df.iloc[2:5,1:3]
# Out:
#    Gender Department
# 2    Male        BCA
# 3  Female        BCA
# 4    Male        BCA

# %%
df.iloc[2:5,1:5]
# Out:
#    Gender Department  Height(CM)  Weight(KG)
# 2    Male        BCA       159.0        78.0
# 3  Female        BCA       147.0        20.0
# 4    Male        BCA       170.0        54.0

# %%
df.iloc[2:8,1:5]
# Out:
#    Gender Department  Height(CM)  Weight(KG)
# 2    Male        BCA       159.0        78.0
# 3  Female        BCA       147.0        20.0
# 4    Male        BCA       170.0        54.0
# 5  Female        BCA       139.0        33.0
# 6    Male        BCA       165.0        50.0
# 7    Male        BCA       152.0        43.0
